# %% [markdown]
# <a href="https://colab.research.google.com/github/MStamirski/Wind-prediction/blob/main/WIND_outcome.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![outcome1.PNG](data:image/png;base64,...)

# %% [markdown]
# LOADING TRAINING DATA
#
# Done ! --------------------------------
#
# LOADING TESTING DATA
#
# Done ! --------------------------------
#
# PREPROCESSING TRAINING DATA
# Source dataset shape:  (3942000, 5)
# Grid of nodes - rows: 15, columns: 15
#
# Inserting nodes coordinates
# index: 3940001 of 3942000, time of step: 0.23714113235473633, total time: 93.11161184310913
# Adding columns from lists, time of step: 3.496208906173706, total time: 96.60793781280518
#
# Done ! --------------------------------
#
# PREPROCESSING TESTING DATA
# Source dataset shape:  (3942000, 5)
# Grid of nodes - rows: 15, columns: 15
#
# Inserting nodes coordinates
# index: 3940001 of 3942000, time of step: 0.2168712615966797, total time: 91.46676325798035
# Adding columns from lists, time of step: 3.384876012802124, total time: 94.85173654556274
#
# Done ! --------------------------------
#
# PREPARING TRAINING DATASETS
#
# Creating prediction dataset: 1.5 hour ahead
# index: 17001 of 17517, time of step: 0.30039501190185547, total time: 6.119624853134155
# creating dataframe from dict, time of step: 1.270101547241211, total time: 7.389845132827759
#
# Creating prediction dataset: 3 hour ahead
# index: 17001 of 17514, time of step: 0.28439974784851074, total time: 6.010160684585571
# creating dataframe from dict, time of step: 1.2342984676361084, total time: 7.244564533233643
#
# Creating prediction dataset: 6 hour ahead
# index: 17001 of 17508, time of step: 0.7813766002655029, total time: 16.9760901927948
# creating dataframe from dict, time of step: 3.5414316654205322, total time: 20.51765275001526
#
# Creating prediction dataset: 12 hour ahead
# index: 17001 of 17496, time of step: 0.8492980003356934, total time: 17.68469476699829
# creating dataframe from dict, time of step: 3.698335886001587, total time: 21.38315510749817
#
# Done ! --------------------------------
#
# PREPARING TESTING DATASETS
#
# Creating prediction dataset: 1.5 hour ahead
# index: 17001 of 17517, time of step: 0.28344297409057617, total time: 5.982027292251587
# creating dataframe from dict, time of step: 1.340061902999878, total time: 7.322227239608765
#
# Creating prediction dataset: 3 hour ahead
# index: 17001 of 17514, time of step: 0.2727019786834717, total time: 6.084288835525513
# creating dataframe from dict, time of step: 1.287247896194458, total time: 7.371628999710083
#
# Creating prediction dataset: 6 hour ahead
# index: 17001 of 17508, time of step: 0.7526836395263672, total time: 16.577227115631104
# creating dataframe from dict, time of step: 3.764777183532715, total time: 20.342145919799805
#
# Creating prediction dataset: 12 hour ahead
# index: 17001 of 17496, time of step: 0.7724111080169678, total time: 16.70915937423706
# creating dataframe from dict, time of step: 3.7077693939208984, total time: 20.417070388793945
#
# Creating baseline datasets
#
# Done ! --------------------------------

# %% [markdown]
# ================= 1.5 hours prediction ========================
#
# Model training...
#
# Model testing...
#
# Done ! --------------------------------

# %% [markdown]
# ![outcome2.PNG](data:image/png;base64,...)

# %% [markdown]
# ![outcome3.PNG](data:image/png;base64,...)

# %% [markdown]
# ================= 3 hours prediction ========================
#
# Model training...
#
# Model testing...
#
# Done ! --------------------------------

# %% [markdown]
# ![outcome4.PNG](data:image/png;base64,...)

# %% [markdown]
# ![outcome5.PNG](data:image/png;base64,...)

# %% [markdown]
# ================= 6 hours prediction ========================
#
# Model training...
#
# Model testing...
#
#
# Done ! --------------------------------

# %% [markdown]
# ![outcome6.PNG](data:image/png;base64,...)

# %% [markdown]
# ![outcome7.PNG](data:image/png;base64,...)

# %% [markdown]
# ================= 12 hours prediction ========================
#
# Model training...
#
# Model testing...
#
# Done ! --------------------------------

# %% [markdown]
# ![outcome8.PNG](data:image/png;base64,...)

# %% [markdown]
# ![outcome9.PNG](data:image/png;base64,...)
